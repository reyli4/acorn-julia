# %%
import pandas as pd

# %%
df = pd.read_csv('./runs/low_RE_high_elec_iter0_defaultsubset/outputs/historical_1980_2019/nyiso_only/load_shedding_year.csv')

# %%
df.iloc[:, 2:].sum().plot()
# Out:
# <Axes: >
