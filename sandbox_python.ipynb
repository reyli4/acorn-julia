# %%
import pandas as pd
import geopandas as gpd

# %%
project_path = '/Users/dcl257/Projects/current_projects/nys-clcpa-2050'

# %%
gdf = gpd.read_file(f"{project_path}/data/nyiso/shapefiles/NYISO_Load_Zone_Dissolved.shp")

# %%
gdf
# Out:
#    ZONE      ZONE_NAME  COLOR  \
# 0     F        Capital    4.0
# 1     C        Central    1.0
# 2     I      Dunwoodie    6.0
# 3     B        Genesee    2.0
# 4     G  Hudson Valley    2.0
# 5     K    Long Island    2.0
# 6     H       Millwood    1.0
# 7     E  Mohawk Valley    6.0
# 8     J  New York City    4.0
# 9     D          North    3.0
# 10    A           West    5.0
#
#                                              geometry
# 0   MULTIPOLYGON (((-74.53729 42.4579, -74.54105 4...
# 1   MULTIPOLYGON (((-78.07425 42.0732, -78.07421 4...
# 2   MULTIPOLYGON (((-73.76768 40.88052, -73.76775 ...
# 3   MULTIPOLYGON (((-78.07407 42.04235, -78.07407 ...
# 4   MULTIPOLYGON (((-73.983 41.3216, -73.98278 41....
# 5   MULTIPOLYGON (((-73.61533 40.59676, -73.61528 ...
# 6   POLYGON ((-73.9121 41.1677, -73.93191 41.2049,...
# 7   MULTIPOLYGON (((-74.81519 41.54383, -74.81921 ...
# 8   MULTIPOLYGON (((-74.13762 40.53519, -74.13602 ...
# ...

# %%
gdf.plot(column='ZONE', legend=True, cmap='Paired')
# Out:
# <Axes: >
